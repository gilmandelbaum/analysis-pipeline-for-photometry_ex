# %% [markdown]
# # Notebook 1 d: Get stim trials from opto-exp

# %%
import dill
import pickle
from pathlib import Path
import itertools

# %%
import Notebook_1_helper_functions as Nb_1

# %%
#parameters: 

# mouse = 'T240'
# data_day = '2019_09_27__T240'
# date = '2019_09_27'

# HowManyBack = 1

# data_dir_output = "/Users/gilmandelbaum/Desktop/outPut"


# Nb0 ="a"

# #Change when updating notebook: 
# Nb1 ="d"

#this will need to be changed in the future to run from the paper mill actually: 

TypeOfStim = 'Consumption'
Trials_filter= 'allTrials'


mouse = 'T196'
data_day = '2019_04_20__T196'
date = '2019_04_20'

HowManyBack = 1


drop2blocks= 'yes'
drop2lastblocks="yes"


data_dir_input = "/Users/gilmandelbaum/Desktop/mice_for_ts"
data_dir_output = "/Users/gilmandelbaum/Desktop/output/"

Nb0 ="a"
Nb1 ="d"

# %%
root = Path(data_dir_output+"/"+mouse+"/"+data_day+'/'+str(HowManyBack)+"_Back")
d = mouse+"_"+date+"Notebook_0_"+Nb0+'.pickle'
my_path = root / d 
# open a file, where you stored the pickled data
fileToOpen = open(my_path, 'rb')
# dump information to that file
behavior_data_trial = pickle.load(fileToOpen)

# %%
if Trials_filter == 'allTrials':
    Nb1 = "a"
elif Trials_filter == 'noENLp':
    Nb1 = "b"
elif Trials_filter == 'onlyENLp':
    Nb1 = "c"

# %%
root = Path(data_dir_output+"/"+mouse+"/"+data_day+'/'+str(HowManyBack)+"_Back")
d = mouse+"_"+date+"Notebook_1_"+Nb1+".pickle"
my_path = root / d 
# open a file, where you stored the pickled data
fileToOpen = open(my_path, 'rb')
# dump information to that file
behavior_data_trial_RIC_LIC_combinations_n = pickle.load(fileToOpen)

# %% [markdown]
# # Because it is an optogenetics analysis:

# %%
if TypeOfStim =='ENLonly':   
    stim_trials = behavior_data_trial[(behavior_data_trial["L_ENL_trig_n_l1"]>0)]
    stim_trials.to_csv("stim_trials.csv")
elif TypeOfStim =='FullStim':
    stim_trials = behavior_data_trial[(behavior_data_trial["L_ENL_trig_n_l1"]>0)]
elif TypeOfStim == 'Consumption':
    stim_trials = behavior_data_trial[(behavior_data_trial['L_Rew_trig_I_l1']>0) & (behavior_data_trial['iReward']>0)]
    stim_trials = behavior_data_trial[behavior_data_trial.index.isin(stim_trials.index+1)]

# %%
stim_trials
# Out:
#      iSpout  iBlock  iTrial  iTrial_post  iReward  iError  I_listeningRig  \
# 36        1       5       5            3        4       0               1
# 42        0       6       5            3        0       2               1
# 61        1       7      11            6        4       0               1
# 68        0       8       7            3        4       0               1
# 80        1       9      10            9        4       0               1
# 85        0      10       5            3        0       2               1
# 95        1      11       6            3        4       0               1
# 108       0      12       8            4        0       5               1
# 119       1      13      10            3        4       0               1
# 126       0      14       5            3        4       0               1
# 180       0      20       7            3        0       4               1
# 190       1      21       5            3        0       2               1
# 200       0      22       6            3        0       3               1
# 214       1      23       6            3        4       0               1
# 221       0      24       6            3        0       3               1
# 230       1      25       7            3        4       0               1
# 239       0      26       6            3        0       3               1
# 274       1      29       5            3        4       0               1
# 282       0      30       6            3        0       3               1
#
#      sCue  T_Cue_Audio  T_Cue_LED  ...  Unnamed: 90  Unnamed: 91  Unnamed: 92  \
# 36      0           75          0  ...            0            0            0
# 42      0           75          0  ...            0            0            0
# 61      0           75          0  ...            0            0            0
# 68      0           75          0  ...            0            0            0
# 80      0           75          0  ...            0            0            0
# 85      0           75          0  ...            0            0            0
# 95      0           75          0  ...            0            0            0
# 108     0           75          0  ...            0            0            0
# 119     0           75          0  ...            0            0            0
# 126     0           75          0  ...            0            0            0
# 180     0           75          0  ...            0            0            0
# 190     0           75          0  ...            0            0            0
# 200     0           75          0  ...            0            0            0
# 214     0           75          0  ...            0            0            0
# 221     0           75          0  ...            0            0            0
# 230     0           75          0  ...            0            0            0
# 239     0           75          0  ...            0            0            0
# 274     0           75          0  ...            0            0            0
# 282     0           75          0  ...            0            0            0
#
#      Unnamed: 93        Date  Mouse  direction  -1_r  SamePastDirection  -1_d
# 36             0  2019_04_20   T196          R     1                1.0   1.0
# 42             0  2019_04_20   T196          R     1                2.0   2.0
# 61             0  2019_04_20   T196          R     1                1.0   1.0
# 68             0  2019_04_20   T196          L     1                1.0   1.0
# 80             0  2019_04_20   T196          R     1                1.0   1.0
# 85             0  2019_04_20   T196          R     1                2.0   2.0
# 95             0  2019_04_20   T196          R     1                1.0   1.0
# 108            0  2019_04_20   T196          R     1                2.0   2.0
# 119            0  2019_04_20   T196          R     1                1.0   1.0
# 126            0  2019_04_20   T196          L     1                1.0   1.0
# 180            0  2019_04_20   T196          R     1                2.0   2.0
# 190            0  2019_04_20   T196          L     1                2.0   2.0
# 200            0  2019_04_20   T196          R     1                2.0   2.0
# 214            0  2019_04_20   T196          R     1                1.0   1.0
# 221            0  2019_04_20   T196          R     1                2.0   2.0
# 230            0  2019_04_20   T196          R     1                1.0   1.0
# 239            0  2019_04_20   T196          R     1                2.0   2.0
# 274            0  2019_04_20   T196          R     1                1.0   1.0
# 282            0  2019_04_20   T196          R     1                2.0   2.0
#
# [19 rows x 99 columns]

# %% [markdown]
# # separate between the right and left and IPSI CONTRA trials.
# The system has a right spout and a left spout. Each of those sides has an IPSI side and CONTRA side compared to the brain.

# %%
behavior_data_trial_stim_RIC_LIC = Nb_1.separate_between_RIC_LIC_blocks(stim_trials)

# %% [markdown]
# # also seperate based on looking back X number of trials.
# For example, looking back one trial: lose switch (22), lose stay (21), win switch (12), win stay (11).

# %%
behavior_data_trial_stim_RIC_LIC_combinations=Nb_1.get_combination_previous_trial(behavior_data_trial_stim_RIC_LIC ,HowManyBack)

# %%
behavior_data_trial_stim_RIC_LIC_combinations_n = Nb_1.get_nTrials_tt(behavior_data_trial_stim_RIC_LIC_combinations)

# %%
behavior_data_trial_RIC_LIC_combinations_n = Nb_1.get_nTrials_ttCombine(behavior_data_trial_RIC_LIC_combinations_n, behavior_data_trial_stim_RIC_LIC_combinations_n)

# %%
#changed based on notebook
Nb1 ="d"

# %%
root = Path(data_dir_output+"/"+mouse+"/"+data_day+'/'+str(HowManyBack)+"_Back")
d = mouse+"_"+date+"Notebook_1_"+Nb1+'.pickle'
#theDataFrame = "Notebook_1_"+Nb1+'.pickle'
my_path = root / d 
my_file = open(my_path, 'wb')
my_file = pickle.dump(behavior_data_trial_RIC_LIC_combinations_n,my_file)
