# %%
import pickle
from pathlib import Path
import pandas as pd 
import os
import sys
import matplotlib.pyplot as plt
import getpass

# %%
#add the github path that will run the notebooks: 
username = getpass.getuser() # gets the username from the current comp 
print (username)
# Out:
# gilmandelbaum

# %%
sys.path.insert(0,'/Users/{:}/github/analysis-pipeline-for-photometry_ex/Nb_data_set/1.data_set_lineplot'.format(username))

# %%
sys.path[0]
# Out:
# '/Users/gilmandelbaum/github/analysis-pipeline-for-photometry_ex/Nb_data_set/1.data_set_lineplot'

# %%
import data_set_lineplot_ic_together_helper_functions as dslhf

# %%
seq_str = '0a1b2a3b4abcd5a6a7a'
period_of_interest = "combined_periods_1"
HowManyBasck=1
folderName="left_dual_color_photo_full_data_set_after_inspection" #folder where the plot data_set will be saved 
path = "/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/"

# %% [markdown]
# # Folder name of analysis:

# %%
analysis_type ="2.dsl__ipsinext(winall_vs_loseall)_contranext(winall_vs_loseall)__ls"

# %%
sys.executable
# Out:
# '/anaconda3/bin/python3'

# %% [markdown]
# # Import the data and where to save it

# %%
path_to_save = path+"/"+folderName+"/"+seq_str #also for loading

# %%
path_to_save
# Out:
# '/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis//left_dual_color_photo_full_data_set_after_inspection/0a1b2a3b4abcd5a6a7a'

# %% [markdown]
# # Import the data and where to save it

# %%
# %%time
root = Path(path_to_save)
d = "data_object_photometry"+"_"+seq_str+'.pickle'
my_path = root / d 
fileToOpen = open(my_path, 'rb')
data_set = pickle.load(fileToOpen)
# Out:
# CPU times: user 14.9 s, sys: 1.53 s, total: 16.4 s
# Wall time: 16.8 s

# %%
y_axis_list = ["df_f","z_score","z_score_sliding_window"]

# %%
alphabet = ["a","b","c","d","e","f","g"]
y_axis = y_axis_list[alphabet.index(seq_str[:seq_str.index('4')][-1])]
print (y_axis)
# Out:
# z_score

# %%
# stash result in a cache directory, for how many back. 
cache_dir_plt = os.path.join(path_to_save,analysis_type,period_of_interest)
if not os.path.exists(cache_dir_plt):
    os.makedirs(cache_dir_plt)

# %%
cache_dir_plt
# Out:
# '/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis//left_dual_color_photo_full_data_set_after_inspection/0a1b2a3b4abcd5a6a7a/2.dsl__ipsinext(winall_vs_loseall)_contranext(winall_vs_loseall)__ls/combined_periods_1'

# %% [markdown]
# # generate data sets of interest

# %%
#combinations = [(2, 2), (2, 1), (1, 2), (1, 1)]

# %%
l_ws_period_d1_data_set= dslhf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           1,2,
                                                                           period_of_interest,"d1 L")
# Out:
# empty
# full
# empty
# empty
# full
# full
# empty
# full
# full
# empty
# empty
# empty
# full
# full
# full
# full
# empty
# full
# empty
# full
# full
# full
# full
# full
# empty
# full
# empty
# empty
# empty
# full
# empty
# full
# empty
# empty
# empty
# full
# empty
# full
# full
# empty

# %%
l_ws_period_d2_data_set= dslhf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           1,2,
                                                                           period_of_interest,"d2 L")
# Out:
# empty
# full
# empty
# empty
# full
# full
# empty
# full
# full
# empty
# empty
# empty
# full
# full
# full
# full
# empty
# full
# empty
# full
# full
# full
# full
# full
# empty
# full
# empty
# empty
# empty
# full
# empty
# full
# empty
# empty
# empty
# full
# empty
# full
# full
# empty

# %%
l_wr_period_d1_data_set= dslhf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           1,3,
                                                                           period_of_interest,"d1 L")
# Out:
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full

# %%
l_wr_period_d2_data_set= dslhf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           1,3,
                                                                           period_of_interest,"d2 L")
# Out:
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full

# %%
l_ls_period_d1_data_set= dslhf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           1,0,
                                                                           period_of_interest,"d1 L")
# Out:
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full

# %%
l_ls_period_d2_data_set= dslhf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           1,0,
                                                                           period_of_interest,"d2 L")
# Out:
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full

# %%
l_lr_period_d1_data_set= dslhf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           1,1,
                                                                           period_of_interest,"d1 L")
# Out:
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# empty
# full
# full
# empty
# empty
# full
# full
# full
# full
# full
# full
# full
# full
# full
# empty
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full

# %%
l_lr_period_d2_data_set= dslhf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           1,1,
                                                                           period_of_interest,"d2 L")
# Out:
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# empty
# full
# full
# empty
# empty
# full
# full
# full
# full
# full
# full
# full
# full
# full
# empty
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full
# full

# %%
def combine_data_of_interest (r_data_set_1, r_data_set_2): 
    
    ipsi_contra_data_set_combined = []
    
    for r_session_1,r_session_2 in zip(r_data_set_1,r_data_set_2):
        ipsi_contra = combine_data_of_interest_helper(r_session_1,r_session_2)
        ipsi_contra_data_set_combined.append(ipsi_contra)
        
    return (ipsi_contra_data_set_combined)

# %%
def combine_data_of_interest_helper (r_session_1, r_session_2):
#combine function: 
#append the win switch (if exists) to the win repeats that do exist.
    ipsi_combined =  pd.concat([r_session_1[0],r_session_2[0]],axis=1)
    contra_combined =  pd.concat([r_session_1[1],r_session_2[1]],axis=1)

    #contra_combined = PhotoData_perTrial_channels[rl][1][tt][period][cell_type]
    return (ipsi_combined,contra_combined)

# %%
l_d1_win_data_set = combine_data_of_interest (l_wr_period_d1_data_set,l_ws_period_d1_data_set)

# %%
l_d2_win_data_set = combine_data_of_interest (l_wr_period_d2_data_set,l_ws_period_d2_data_set)

# %%
l_d1_lose_data_set = combine_data_of_interest (l_ls_period_d1_data_set,l_lr_period_d1_data_set)

# %%
l_d2_lose_data_set = combine_data_of_interest (l_ls_period_d2_data_set,l_lr_period_d2_data_set)

# %% [markdown]
# # Calculate means per each session

# %%
l_d1_win_data_set_df = dslhf.calculate_mean_data_set(l_d1_win_data_set)

# %%
l_d2_win_data_set_df = dslhf.calculate_mean_data_set(l_d2_win_data_set)

# %%
l_d1_lose_data_set_df = dslhf.calculate_mean_data_set(l_d1_lose_data_set)

# %%
l_d2_lose_data_set_df = dslhf.calculate_mean_data_set(l_d2_lose_data_set)

# %% [markdown]
# # Calculate means and sem on the data set

# %%
l_d1_win_mean_sem = dslhf.calculate_mean_sem (l_d1_win_data_set_df)

# %%
l_d2_win_mean_sem = dslhf.calculate_mean_sem (l_d2_win_data_set_df)

# %%
l_d1_lose_mean_sem = dslhf.calculate_mean_sem (l_d1_lose_data_set_df)

# %%
l_d2_lose_mean_sem = dslhf.calculate_mean_sem (l_d2_lose_data_set_df)

# %% [markdown]
# # make_sem_traces

# %%
l_d1_win_mean_sem_traces = dslhf.make_sem_traces(l_d1_win_mean_sem)

# %%
l_d2_win_mean_sem_traces = dslhf.make_sem_traces(l_d2_win_mean_sem)

# %%
l_d1_lose_mean_sem_traces = dslhf.make_sem_traces(l_d1_lose_mean_sem)

# %%
l_d2_lose_mean_sem_traces = dslhf.make_sem_traces(l_d2_lose_mean_sem)

# %% [markdown]
# # plots

# %%
dslhf.plot_win_lose_together_ipsi_prev(l_d1_win_mean_sem,l_d1_win_mean_sem_traces,
                                       l_d1_lose_mean_sem,l_d1_lose_mean_sem_traces,
                                       "left_win_lose_ipsi_prev",period_of_interest,"D1",y_axis,cache_dir_plt)

# %%
dslhf.plot_win_lose_together_ipsi_prev(l_d2_win_mean_sem,l_d2_win_mean_sem_traces,
                                       l_d2_lose_mean_sem,l_d2_lose_mean_sem_traces,
                                       "left_win_lose_ipsi_prev",period_of_interest,"D2",y_axis,cache_dir_plt)

# %%
dslhf.plot_win_lose_together_contra_prev(l_d1_win_mean_sem,l_d1_win_mean_sem_traces,
                                         l_d1_lose_mean_sem,l_d1_lose_mean_sem_traces,
                                         "left_win_lose_contra_prev",period_of_interest,"D1",y_axis,cache_dir_plt)

# %%
dslhf.plot_win_lose_together_contra_prev(l_d2_win_mean_sem,l_d2_win_mean_sem_traces,
                                         l_d2_lose_mean_sem,l_d2_lose_mean_sem_traces,
                                         "left_win_lose_contra_prev",period_of_interest,"D2",y_axis,cache_dir_plt)

# %%
dslhf.plot_win_lose_together_ipsi_next(l_d1_win_mean_sem,l_d1_win_mean_sem_traces,
                                       l_d1_lose_mean_sem,l_d1_lose_mean_sem_traces,
                                       "left_win_lose_ipsi_next",period_of_interest,"D1",y_axis,cache_dir_plt)

# %%
dslhf.plot_win_lose_together_ipsi_next(l_d2_win_mean_sem,l_d2_win_mean_sem_traces,
                                       l_d2_lose_mean_sem,l_d2_lose_mean_sem_traces,
                                       "left_win_lose_ipsi_next",period_of_interest,"D2",y_axis,cache_dir_plt)

# %%
dslhf.plot_win_lose_together_contra_next(l_d1_win_mean_sem,l_d1_win_mean_sem_traces,
                                         l_d1_lose_mean_sem,l_d1_lose_mean_sem_traces,
                                         "left_win_lose_contra_next",period_of_interest,"D1",y_axis,cache_dir_plt)

# %%
dslhf.plot_win_lose_together_contra_next(l_d2_win_mean_sem,l_d2_win_mean_sem_traces,
                                         l_d2_lose_mean_sem,l_d2_lose_mean_sem_traces,
                                         "left_win_lose_contra_next",period_of_interest,"D2",y_axis,cache_dir_plt)
