# %%
import pickle
from pathlib import Path
import pandas as pd 
import os
import sys

# %%
import data_set_generate_helper_functions as ghf

# %%
sys.executable
# Out:
# '/anaconda3/bin/python3'

# %% [markdown]
# # Import the data and where to save it

# %%
path = "/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/"

# %% [markdown]
# # Update depending on analysis:

# %%
seq_str = '0a1b2a3a4abcde5a6a7b'
HowManyBack=1

# %%
folderName="dual_color_photo_full_data_set" #folder where the plot data_set will be saved

# %%
path_to_save = path+"/"+folderName+"/"+seq_str

# %% [markdown]
# # import the data table:

# %%
#name of xlsx file that has the sessions we want to run: 
MasterSheetName= 'dual_color_photo_master_spread_sheet'

# %%
Mouse_Date_FileName = pd.read_excel(path+'/'+MasterSheetName+'.xlsx') #mdf is mouse data file

# %%
Mouse_Date_FileName
# Out:
#    Mouse    Date    File name
# 0   T163  181128  T163-115220
# 1   T163  181130  T163-133215
# 2   T163  181203  T163-115901
# 3   T163  181204  T163-114628
# 4   T163  181206  T163-112720
# 5   T163  181207  T163-123432
# 6   T163  181210  T163-102536
# 7   T163  181213  T163-094646
# 8   T164  181127  T164-153101
# 9   T164  181128  T164-122054
# 10  T164  181204  T164-121548
# 11  T164  181205  T164-123550
# 12  T164  181210  T164-105324
# 13  T164  181213  T164-101804
# 14  T169  190201  T169-141602
# 15  T169  190212  T169-145045
# 16  T169  190213  T169-141800
# 17  T169  190219  T169-140515
# 18  T169  190220  T169-141850
# 19  T169  190222  T169-134725
# 20  T169  190225  T169-145248
# 21  T169  190227  T169-155731
# 22  T169  190228  T169-142051
# 23  T171  190122  T171-165215
# 24  T171  190128  T171-144901
# 25  T171  190130  T171-145252
# 26  T171  190211  T171-143016
# 27  T171  190220  T171-153511
# 28  T171  190221  T171-152107
# 29  T171  190225  T171-152054
# 30  T171  190226  T171-145215
# 31  T171  190227  T171-162455
# 32  T186  190322  T186-164847
# 33  T186  190327  T186-150703
# 34  T186  190328  T186-144534
# 35  T186  190401  T186-142719
# 36  T186  190402  T186-140234
# 37  T186  190405  T186-135725
# 38  T187  190322  T187-172139
# 39  T187  190325  T187-153540
# 40  T187  190328  T187-152018
# 41  T187  190401  T187-150132
# 42  T187  190402  T187-142756
# 43  T187  190403  T187-143148
# 44  T187  190404  T187-142541
# 45  T196  190422  T196-172239
# 46  T196  190424  T196-170637
# 47  T196  190429  T196-151455
# 48  T196  190430  T196-145937
# 49  T196  190507  T196-144204
# 50  T196  190509  T196-144508
# 51  T240  190821  T240-144433
# 52  T240  190822  T240-142317
# 53  T240  190827  T240-141253
# 54  T240  190830  T240-142919
# 55  T240  190913  T240-144701
# 56  T240  190927  T240-145905

# %% [markdown]
# # Import the full data structure for each session:

# %%
# %%time
PhotoData_perTrial_channels_data_set = ghf.extract_data_set(Mouse_Date_FileName,path,HowManyBack,seq_str)
# Out:
# session number 1 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T163/2018_11_28__T163/1_Back/T163_2018_11_28Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 2 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T163/2018_11_30__T163/1_Back/T163_2018_11_30Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 3 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T163/2018_12_03__T163/1_Back/T163_2018_12_03Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 4 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T163/2018_12_04__T163/1_Back/T163_2018_12_04Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 5 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T163/2018_12_06__T163/1_Back/T163_2018_12_06Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 6 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T163/2018_12_07__T163/1_Back/T163_2018_12_07Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 7 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T163/2018_12_10__T163/1_Back/T163_2018_12_10Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 8 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T163/2018_12_13__T163/1_Back/T163_2018_12_13Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 9 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T164/2018_11_27__T164/1_Back/T164_2018_11_27Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 10 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T164/2018_11_28__T164/1_Back/T164_2018_11_28Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 11 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T164/2018_12_04__T164/1_Back/T164_2018_12_04Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 12 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T164/2018_12_05__T164/1_Back/T164_2018_12_05Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 13 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T164/2018_12_10__T164/1_Back/T164_2018_12_10Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 14 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T164/2018_12_13__T164/1_Back/T164_2018_12_13Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 15 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T169/2019_02_01__T169/1_Back/T169_2019_02_01Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 16 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T169/2019_02_12__T169/1_Back/T169_2019_02_12Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 17 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T169/2019_02_13__T169/1_Back/T169_2019_02_13Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 18 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T169/2019_02_19__T169/1_Back/T169_2019_02_19Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 19 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T169/2019_02_20__T169/1_Back/T169_2019_02_20Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 20 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T169/2019_02_22__T169/1_Back/T169_2019_02_22Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# session number 21 was imported (out of 57)
# /Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/T169/2019_02_25__T169/1_Back/T169_2019_02_25Notebook_6_a_seq0a1b2a3a4abcde5a6a.pickle
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/github/analysis-pipeline-for-photometry_ex/Nb_data_set/data_set_generate/data_set_generate_helper_functions.py in extract_data_set(Mouse_Date_FileName, data_to_be_plotted, HowManyBack, seq_str)
#      46         fileToOpen = open(my_path, 'rb')
#      47         # load the pickle:
# ---> 48         PhotoData_perTrial_channels = pickle.load(fileToOpen)
#      49
#      50         counter += 1
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _new_Index(cls, d)
#     155
#     156
# --> 157 def _new_Index(cls, d):
#     158     """
#     159     This is called upon unpickling, rather than the default which doesn't
#
# KeyboardInterrupt:

# %%
data_set = PhotoData_perTrial_channels_data_set.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8e0b72ec193a> in <module>
# ----> 1 data_set = PhotoData_perTrial_channels_data_set.copy()
#
# NameError: name 'PhotoData_perTrial_channels_data_set' is not defined

# %%
list(data_set[0][0][0][0].keys())

# %%
len(list(data_set[0][0][0][0].keys()))

# %%
if not os.path.exists(path_to_save):
    os.makedirs(path_to_save)

# %%
# %%time
root = Path(path_to_save)
d = "data_set"+"_"+seq_str+'.pickle'
my_path = root / d 
my_file = open(my_path, 'wb')
my_file = pickle.dump((data_set),my_file)
