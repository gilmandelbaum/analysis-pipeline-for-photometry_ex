# %%
import pickle
from pathlib import Path
import pandas as pd 
import os
import sys
import matplotlib.pyplot as plt
from statistics import mean
import getpass

# %%
#add the github path that will run the notebooks: 
username = getpass.getuser() # gets the username from the current comp 
print (username)
# Out:
# gilmandelbaum

# %%
sys.path.insert(0,'/Users/{:}/github/analysis-pipeline-for-photometry_ex/Nb_data_set/2.data_set_calculations'.format(username))

# %%
import data_set_calculations_helper_functions as dschf

# %% [markdown]
# # Change based on analysis:

# %%
seq_str = '0a1b2a3b4abcd5a6a7a'
period_of_interest = "combined_periods_1"

# %%
HowManyBack=1
folderName="right_dual_color_photo_full_data_set_after_inspection" #folder where the plot data_set will be saved 
path = "/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis/"

# %% [markdown]
# # Folder name of analysis:

# %%
analysis_type ="data_set_calculations"

# %%
sys.executable
# Out:
# '/anaconda3/bin/python3'

# %% [markdown]
# # Import the data and where to save it

# %%
path_to_save = path+"/"+folderName+"/"+seq_str #also for loading

# %%
path_to_save
# Out:
# '/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis//right_dual_color_photo_full_data_set_after_inspection/0a1b2a3b4abcd5a6a7a'

# %%
# %%time
root = Path(path_to_save)
d = "data_object_photometry"+"_"+seq_str+'.pickle'
my_path = root / d 
fileToOpen = open(my_path, 'rb')
data_set = pickle.load(fileToOpen)
# Out:
# CPU times: user 11.8 s, sys: 944 ms, total: 12.7 s
# Wall time: 12.8 s

# %%
# stash result in a cache directory, for how many back. 
cache_dir_plt = os.path.join(path_to_save,analysis_type,period_of_interest)
if not os.path.exists(cache_dir_plt):
    os.makedirs(cache_dir_plt)

# %%
cache_dir_plt
# Out:
# '/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis//right_dual_color_photo_full_data_set_after_inspection/0a1b2a3b4abcd5a6a7a/data_set_calculations/combined_periods_1'

# %% [markdown]
# # generate data sets of interest

# %%
r_ls_period_d1_data_set= dschf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           0,0,
                                                                           period_of_interest,"d1 R")

# %%
r_ls_period_d2_data_set= dschf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           0,0,
                                                                           period_of_interest,"d2 R")

# %%
r_wr_period_d1_data_set= dschf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           0,3,
                                                                           period_of_interest,"d1 R")

# %%
r_wr_period_d2_data_set= dschf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           0,3,
                                                                           period_of_interest,"d2 R")

# %% [markdown]
# # Calculations avg per session

# %%
def avg_pre_post_choice_perSession(data_ipsi_contra):
    
    pre=round(data_ipsi_contra.loc[0:199].mean().mean(),3)
    post=round(data_ipsi_contra.loc[201:401].mean().mean(),3)

    return(pre,post)

# %%
def calculate_value_on_data_set_2 (ipsi_contra_data_set,function,column_name):
    
    df_ipsi_next_list_pre = []
    df_ipsi_next_list_post = []
    df_contra_next_list_pre = []
    df_contra_next_list_post = []
    
    df_output = pd.DataFrame()

    for data_ipsi_contra in ipsi_contra_data_set:
        value_ipsi_next_pre = function(data_ipsi_contra[0])[0]
        value_ipsi_next_post = function(data_ipsi_contra[0])[1]
        
        value_contra_next_pre = function(data_ipsi_contra[1])[0]
        value_contra_next_post = function(data_ipsi_contra[1])[1]
        
        #organize into a data frame: 
        df_ipsi_next_list_pre.append(value_ipsi_next_pre)
        df_ipsi_next_list_post.append(value_ipsi_next_post)
        
        df_contra_next_list_pre.append(value_contra_next_pre)
        df_contra_next_list_post.append(value_contra_next_post)
        
    df_output ["ipsi_pre_"+column_name] = df_ipsi_next_list_pre
    df_output ["ipsi_post_"+column_name] = df_ipsi_next_list_post
    
    df_output ["contra_pre_"+column_name] = df_contra_next_list_pre
    df_output ["contra_post_"+column_name] = df_contra_next_list_post
    #save outputs..      
    return (df_output)

# %%
r_ls_period_d1_avgSig_pre_post_choice_perSession = calculate_value_on_data_set_2(r_ls_period_d1_data_set,
                                                                 avg_pre_post_choice_perSession,
                                                                 "r_ls_d1")

# %%
r_ls_period_d2_avgSig_pre_post_choice_perSession = calculate_value_on_data_set_2(r_ls_period_d2_data_set,
                                                                 avg_pre_post_choice_perSession,
                                                                  "r_ls_d2")

# %%
r_wr_period_d1_avgSig_pre_post_choice_perSession = calculate_value_on_data_set_2(r_wr_period_d1_data_set,
                                                                 avg_pre_post_choice_perSession,
                                                                 "r_wr_d1")

# %%
r_wr_period_d2_avgSig_pre_post_choice_perSession = calculate_value_on_data_set_2(r_wr_period_d2_data_set,
                                                                 avg_pre_post_choice_perSession,
                                                                  "r_wr_d2")

# %%
result = pd.concat([r_ls_period_d1_avgSig_pre_post_choice_perSession,
                    r_ls_period_d2_avgSig_pre_post_choice_perSession,
                    r_wr_period_d1_avgSig_pre_post_choice_perSession,
                    r_wr_period_d2_avgSig_pre_post_choice_perSession],axis=1)

# %%
result
# Out:
#     ipsi_pre_r_ls_d1  ipsi_post_r_ls_d1  contra_pre_r_ls_d1  \
# 0             -0.290              0.700              -0.229
# 1              0.109              1.057               0.178
# 2             -0.201              0.792              -0.318
# 3             -0.120              1.080              -0.003
# 4             -0.050              1.124              -0.258
# 5              0.030              1.144              -0.097
# 6              0.193              1.043              -0.090
# 7             -0.286              0.893              -0.296
# 8              0.191              1.275              -0.060
# 9              0.196              1.306              -0.028
# 10            -0.044              1.042               0.438
# 11            -0.318              0.789              -0.008
# 12             0.003              0.745              -0.153
# 13             0.187              0.505               0.118
# 14            -0.029              0.565              -0.084
# 15             0.146              0.462              -0.136
# 16             0.075              0.471              -0.108
# 17             0.315              0.549              -0.360
# 18             0.371              0.511               0.100
# 19             0.125              1.100               0.167
# 20             0.161              0.862               0.074
# 21             0.131              0.872               0.101
# 22             0.063              1.045              -0.051
# 23             0.077              0.823               0.044
# 24             0.058              1.063               0.052
# 25            -0.096              0.961               0.059
# 26            -0.132              1.009               0.168
# 27             0.095              1.020               0.245
# 28            -0.096              0.258               0.141
# 29            -0.024              1.487              -0.105
# 30            -0.008              1.009              -0.042
# 31            -0.230              1.425              -0.040
# 32             0.014              0.879              -0.139
# 33            -0.178              1.029               0.113
# 34             0.012              0.644               0.242
# 35             0.023              0.500              -0.091
# 36             0.008              0.499              -0.052
# 37            -0.084              0.484               0.001
# 38            -0.062              0.338               0.004
# 39            -0.142              0.448              -0.169
#
#     contra_post_r_ls_d1  ipsi_pre_r_ls_d2  ipsi_post_r_ls_d2  \
# 0                 0.609            -0.845              0.822
# 1                 1.078            -0.510              1.265
# 2                 0.645            -0.839              0.879
# 3                 1.026            -0.734              1.069
# 4                 0.907            -0.660              1.304
# 5                 1.139            -0.350              1.535
# 6                 0.861            -0.488              1.087
# 7                -0.469            -0.557              0.791
# 8                 0.039            -0.153              1.244
# 9                 0.051             0.073              1.307
# 10                0.149            -0.231              1.177
# 11                0.072            -0.519              1.131
# 12                0.886             0.290              1.140
# 13                0.724             0.614              1.135
# 14                0.930            -0.475              0.925
# 15                0.810             0.231              1.079
# 16                0.831             0.033              0.933
# 17                0.711            -0.234              0.899
# 18                0.955             0.459              1.423
# 19                1.032             0.048              0.933
# 20                0.798             0.656              1.373
# 21                0.768             0.075              1.755
# 22                0.966            -0.215              1.310
# 23                0.832            -0.196              0.788
# 24                0.771            -0.434              1.449
# 25                0.884            -0.258              0.852
# 26                0.601            -0.545              0.666
# 27                0.599            -0.417              1.937
# 28                0.249            -0.255              0.568
# 29                0.834            -0.482              1.171
# 30                0.547            -0.260              1.291
# 31                0.869            -0.575              1.590
# 32                0.643            -0.586              0.954
# 33                0.528            -0.496              0.741
# 34                0.422            -0.164              0.954
# 35                0.738            -0.275              0.903
# 36                0.392            -0.321              1.423
# 37                0.933            -0.489              1.174
# 38                0.589            -0.378              1.151
# 39                0.555            -0.305              1.316
#
#     contra_pre_r_ls_d2  contra_post_r_ls_d2  ipsi_pre_r_wr_d1  \
# 0               -0.536                0.138            -0.232
# 1               -0.254                0.649            -0.173
# 2               -0.832                0.319            -0.338
# 3               -0.544                0.680            -0.281
# 4               -0.785                0.044            -0.246
# 5               -0.658                0.466            -0.164
# 6               -0.557                0.429            -0.199
# 7               -0.477                0.523             0.250
# 8               -0.377                0.861             0.217
# 9                0.462                1.138             0.341
# 10               0.295                1.204             0.405
# 11               0.116                0.767             0.598
# 12              -0.452                0.533            -0.061
# 13              -0.340                0.350            -0.044
# 14              -0.393                0.532             0.017
# 15              -0.413                0.467             0.016
# 16              -0.456                0.307            -0.036
# 17              -0.559                0.316            -0.081
# 18               0.277                1.066             0.155
# 19              -0.203                0.659            -0.080
# 20              -0.499                0.767            -0.137
# 21              -0.391                0.955            -0.048
# 22              -0.547                0.580            -0.038
# 23               0.090                0.879            -0.049
# 24              -0.416                0.626            -0.118
# 25              -0.241                0.916            -0.009
# 26              -0.401                0.779            -0.078
# 27               0.143                1.491            -0.036
# 28               0.308                0.733             0.004
# 29              -0.369                0.879            -0.064
# 30              -0.083                0.803             0.021
# 31              -0.193                0.979             0.034
# 32              -0.270                0.526            -0.122
# 33              -0.282                0.660            -0.092
# 34              -0.077                0.860             0.024
# 35              -0.069                1.019            -0.136
# 36              -0.350                1.057            -0.066
# 37              -0.172                1.394            -0.050
# 38               0.333                1.321            -0.021
# 39              -0.175                1.587             0.022
#
#     ipsi_post_r_wr_d1  contra_pre_r_wr_d1  contra_post_r_wr_d1  \
# 0               0.942              -0.364                0.599
# 1               1.195              -0.193                1.138
# 2               1.239              -0.402                0.788
# 3               1.202              -0.327                0.952
# 4               1.426              -0.195                0.876
# 5               1.290              -0.107                1.166
# 6               1.109              -0.144                0.969
# 7              -0.244              -0.222                1.314
# 8               0.104              -0.199                1.430
# 9               0.046              -0.260                1.460
# 10              0.203               0.049                1.205
# 11              0.206              -0.258                1.024
# 12              1.111              -0.090                0.744
# 13              1.112               0.020                0.604
# 14              1.254              -0.060                0.561
# 15              1.036               0.045                0.602
# 16              1.092              -0.042                0.642
# 17              1.206               0.065                0.673
# 18              1.175               0.064                0.641
# 19              0.975              -0.054                1.099
# 20              0.906               0.074                0.884
# 21              0.750              -0.016                0.900
# 22              0.846               0.066                0.879
# 23              0.941               0.138                0.681
# 24              0.657              -0.158                1.064
# 25              0.917              -0.095                0.970
# 26              0.668              -0.178                1.086
# 27              0.407              -0.127                1.365
# 28              0.300              -0.029                0.543
# 29              0.756              -0.144                1.481
# 30              0.607              -0.035                1.088
# 31              0.756              -0.202                1.449
# 32              0.563              -0.049                1.094
# 33              0.588               0.081                1.235
# 34              0.600               0.144                0.584
# 35              0.959               0.072                0.810
# 36              0.768              -0.011                0.630
# 37              1.040              -0.037                0.832
# 38              0.779               0.004                0.561
# 39              0.546              -0.066                0.597
#
#     ipsi_pre_r_wr_d2  ipsi_post_r_wr_d2  contra_pre_r_wr_d2  \
# 0             -0.680              0.601              -0.713
# 1             -0.577              0.894              -0.586
# 2             -0.737              0.917              -0.700
# 3             -0.648              0.770              -0.702
# 4             -0.685              0.817              -0.514
# 5             -0.569              0.873              -0.457
# 6             -0.537              0.828              -0.506
# 7              0.136              0.522              -0.149
# 8             -0.188              0.886              -0.201
# 9             -0.001              0.847              -0.325
# 10             0.041              0.720              -0.031
# 11             0.134              0.696              -0.258
# 12            -0.285              0.672              -0.300
# 13            -0.357              0.644              -0.238
# 14            -0.211              0.884              -0.259
# 15            -0.104              0.739              -0.297
# 16            -0.302              0.600               0.032
# 17            -0.076              0.826               0.085
# 18            -0.002              0.768              -0.092
# 19            -0.408              0.335              -0.139
# 20            -0.275              0.464              -0.087
# 21            -0.246              0.770              -0.283
# 22            -0.160              0.370               0.020
# 23            -0.077              0.277              -0.082
# 24            -0.479              0.300               0.017
# 25            -0.329              0.296              -0.057
# 26            -0.425              0.274               0.026
# 27            -0.322              0.557              -0.305
# 28            -0.162              0.721              -0.195
# 29            -0.276              0.620              -0.532
# 30            -0.108              0.893              -0.293
# 31            -0.189              0.910              -0.452
# 32            -0.261              0.646              -0.287
# 33            -0.245              0.726              -0.388
# 34            -0.123              0.921               0.063
# 35            -0.278              1.080              -0.310
# 36            -0.224              1.126              -0.151
# 37            -0.223              1.147              -0.484
# 38             0.018              0.957              -0.305
# 39            -0.107              1.033              -0.301
#
#     contra_post_r_wr_d2
# 0                 1.090
# 1                 1.675
# 2                 1.262
# 3                 1.363
# 4                 1.561
# 5                 1.683
# 6                 1.500
# 7                 0.940
# 8                 1.013
# 9                 0.892
# 10                1.126
# 11                0.887
# 12                1.558
# 13                0.988
# 14                1.634
# 15                1.194
# 16                1.117
# 17                1.028
# 18                1.064
# 19                0.626
# 20                0.505
# 21                0.870
# 22                0.572
# 23                0.479
# 24                0.771
# 25                0.349
# 26                0.751
# 27                1.183
# 28                0.800
# 29                1.175
# 30                1.259
# 31                1.466
# 32                1.242
# 33                1.398
# 34                0.778
# 35                1.167
# 36                0.966
# 37                0.984
# 38                0.723
# 39                0.902

# %%
result.to_csv(cache_dir_plt+"/data_set_calculations_signal_pre_post_choice_right_side.csv")
