# %%
import pickle
from pathlib import Path
import pandas as pd 
import os
import sys
import matplotlib.pyplot as plt
from statistics import mean
import getpass

# %%
#add the github path that will run the notebooks: 
username = getpass.getuser() # gets the username from the current comp 
print (username)
# Out:
# gilmandelbaum

# %%
sys.path.insert(0,'/Users/{:}/github/analysis-pipeline-for-photometry_ex/Nb_data_set/2.data_set_calculations'.format(username))

# %%
import data_set_calculations_helper_functions as dschf

# %%
seq_str = '0a1b2a3b4abcd5a6a7a'
period_of_interest = "combined_periods_1"
HowManyBack=1
folderName="right_dual_color_photo_full_data_set_after_inspection" #folder where the plot data_set will be saved 
path = "/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis_3/"

# %% [markdown]
# # Folder name of analysis:

# %%
analysis_type ="data_set_calculations"

# %%
sys.executable
# Out:
# '/anaconda3/bin/python3'

# %% [markdown]
# # Import the data and where to save it

# %%
path_to_save = path+"/"+folderName+"/"+seq_str #also for loading

# %%
path_to_save
# Out:
# '/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis_3//right_dual_color_photo_full_data_set_after_inspection/0a1b2a3b4abcd5a6a7a'

# %% [markdown]
# # Import the data and where to save it

# %%
# %%time
root = Path(path_to_save)
d = "data_set"+"_"+seq_str+'.pickle'
my_path = root / d 
fileToOpen = open(my_path, 'rb')
data_set = pickle.load(fileToOpen)
# Out:
# CPU times: user 21 s, sys: 2.14 s, total: 23.1 s
# Wall time: 42.5 s

# %%
#y_axis_list = ["df_f","z_score","z_score_sliding_window"]

# %%
# alphabet = ["a","b","c","d","e","f","g"]
# y_axis = y_axis_list[alphabet.index(seq_str[:seq_str.index('4')][-1])]
# print (y_axis)

# %%
#period_of_interest="combined_periods_1"
#period_of_interest = "pre_firstENLp_tag"
#period_of_interest="last_200_bins_ENL_tag"
#period_of_interest = "first_15_bins_Cue_to_Sel_tag"
#period_of_interest="first_15_bins_Cue_to_Sel_fromPrevTrial_tag"
#period_of_interest="Real_nTrials"
#period_of_interest="Cue_to_Sel_tag"
#period_of_interest="Cue_to_Sel_fromPrevTrial_tag"

# %%
# stash result in a cache directory, for how many back. 
cache_dir_plt = os.path.join(path_to_save,analysis_type,period_of_interest)
if not os.path.exists(cache_dir_plt):
    os.makedirs(cache_dir_plt)

# %%
cache_dir_plt
# Out:
# '/Volumes/GilInVivoPaper.large/2.Photometry_in_str/2.dual_color_photo_full_data_set_analysis_3//right_dual_color_photo_full_data_set_after_inspection/0a1b2a3b4abcd5a6a7a/data_set_calculations/combined_periods_1'

# %%
#from sklearn.metrics import auc

# %% [markdown]
# # generate data sets of interest

# %%
r_ls_period_d1_data_set= dschf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           0,0,
                                                                           period_of_interest,"d1 R")

# %%
r_ls_period_d2_data_set= dschf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           0,0,
                                                                           period_of_interest,"d2 R")

# %%
r_wr_period_d1_data_set= dschf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           0,3,
                                                                           period_of_interest,"d1 R")

# %%
r_wr_period_d2_data_set= dschf.extract_data_of_interest_ipsi_contra_data_set(data_set,
                                                                           0,3,
                                                                           period_of_interest,"d2 R")

# %%
def max_value_per_session (data_ipsi_contra):
    idxmax_value_list = list(data_ipsi_contra.loc[200:500,:].idxmax())
    li =[]
    for c,i in enumerate (idxmax_value_list): #c is the count, i is the index of max value in each session avg 
        maxi = data_ipsi_contra.iloc[(i-10):(i+11),c].mean()
        li.append(maxi)
    li_mean = round(mean(li),3)
    return (li_mean)

# %%
def calculate_value_on_data_set (ipsi_contra_data_set,column_name): #
    
    df_ipsi_next_list = []
    df_contra_next_list = []
    df_output = pd.DataFrame()

    for data_ipsi_contra in ipsi_contra_data_set:
        value_ipsi_next = max_value_per_session(data_ipsi_contra[0])
        value_contra_next = max_value_per_session(data_ipsi_contra[1])
        #organize into a data frame: 
        df_ipsi_next_list.append(value_ipsi_next)
        df_contra_next_list.append(value_contra_next)
    df_output ["ipsi_"+column_name] = df_ipsi_next_list
    df_output ["contra_"+column_name] = df_contra_next_list
    #save outputs..      
    return (df_output)

# %%
r_ls_period_d1_data_set_peak_value_after_choice = calculate_value_on_data_set(r_ls_period_d1_data_set,
                                                                              "ls_d1_right")

# %%
r_ls_period_d2_data_set_peak_value_after_choice = calculate_value_on_data_set(r_ls_period_d2_data_set,
                                                                              "ls_d2_right")

# %%
r_wr_period_d1_data_set_peak_value_after_choice = calculate_value_on_data_set(r_wr_period_d1_data_set,
                                                                              "wr_d1_right")

# %%
r_wr_period_d2_data_set_peak_value_after_choice = calculate_value_on_data_set(r_wr_period_d2_data_set,
                                                                              "wr_d2_right")

# %%
result = pd.concat([r_ls_period_d1_data_set_peak_value_after_choice,
                    r_ls_period_d2_data_set_peak_value_after_choice,
                    r_wr_period_d1_data_set_peak_value_after_choice,
                    r_wr_period_d2_data_set_peak_value_after_choice],axis=1)

# %%
result
# Out:
#     ipsi_ls_d1_right  contra_ls_d1_right  ipsi_ls_d2_right  \
# 0              2.324               2.281             1.728
# 1              2.888               2.536             1.977
# 2              2.324               2.264             1.723
# 3              2.826               2.713             1.789
# 4              2.739               2.751             2.025
# 5              2.799               2.667             2.229
# 6              2.719               2.369             1.791
# 7              2.192               0.418             1.832
# 8              2.789               0.968             2.202
# 9              2.727               0.993             2.029
# 10             2.697               1.376             2.119
# 11             2.119               1.188             2.035
# 12             2.324               2.510             2.183
# 13             1.938               2.214             2.125
# 14             2.020               2.696             1.875
# 15             2.068               2.448             2.185
# 16             2.228               2.351             1.913
# 17             2.050               2.443             1.908
# 18             2.038               2.477             2.581
# 19             2.526               2.545             1.667
# 20             2.429               2.569             2.081
# 21             2.734               2.332             3.158
# 22             2.772               2.584             2.393
# 23             2.356               2.319             1.502
# 24             2.524               1.894             2.431
# 25             2.433               2.409             1.822
# 26             2.647               1.965             1.391
# 27             2.213               1.840             3.145
# 28             1.831               2.005             1.798
# 29             3.212               2.177             2.165
# 30             2.794               1.977             2.366
# 31             3.159               2.175             2.692
# 32             2.526               2.105             2.006
# 33             2.567               1.946             1.594
# 34             2.362               1.851             2.241
# 35             1.869               2.418             1.873
# 36             2.122               1.766             2.735
# 37             1.930               2.459             2.184
# 38             1.788               2.168             2.297
# 39             1.899               2.205             2.257
#
#     contra_ls_d2_right  ipsi_wr_d1_right  contra_wr_d1_right  \
# 0                0.963             2.397               2.033
# 1                1.247             2.632               2.592
# 2                0.983             2.511               2.097
# 3                1.472             2.678               2.457
# 4                0.590             2.734               2.220
# 5                1.034             2.673               2.610
# 6                0.946             2.550               2.453
# 7                1.423             1.087               2.097
# 8                1.722             1.515               2.668
# 9                1.900             1.471               2.448
# 10               2.094             1.529               2.602
# 11               1.489             1.810               2.163
# 12               1.176             2.532               2.244
# 13               1.132             2.540               1.976
# 14               1.266             2.776               1.910
# 15               1.366             2.528               2.027
# 16               1.025             2.494               2.107
# 17               0.972             2.589               2.127
# 18               1.777             2.583               2.147
# 19               1.272             2.265               2.356
# 20               1.612             2.233               2.304
# 21               1.910             2.428               2.302
# 22               1.360             2.201               2.321
# 23               1.590             2.324               2.122
# 24               1.437             2.003               2.421
# 25               1.708             2.264               2.360
# 26               1.565             2.072               2.574
# 27               2.221             1.885               2.682
# 28               1.588             1.847               1.970
# 29               2.052             2.016               3.181
# 30               1.564             1.965               2.704
# 31               1.723             2.050               3.015
# 32               1.408             1.890               2.617
# 33               1.342             1.971               2.909
# 34               1.984             2.334               2.115
# 35               1.959             2.413               2.437
# 36               2.176             2.209               2.276
# 37               2.417             2.456               2.279
# 38               2.446             2.306               2.118
# 39               2.685             2.095               2.187
#
#     ipsi_wr_d2_right  contra_wr_d2_right
# 0              1.523               2.134
# 1              1.593               2.533
# 2              1.820               2.181
# 3              1.469               2.240
# 4              1.560               2.388
# 5              1.526               2.502
# 6              1.552               2.213
# 7              1.596               1.992
# 8              1.916               2.003
# 9              1.871               1.769
# 10             1.693               2.032
# 11             1.680               1.741
# 12             1.434               2.589
# 13             1.369               2.014
# 14             1.740               2.609
# 15             1.548               2.336
# 16             1.485               2.047
# 17             1.477               1.799
# 18             1.510               2.033
# 19             1.115               1.564
# 20             1.171               1.175
# 21             1.427               1.725
# 22             1.050               1.323
# 23             1.028               1.297
# 24             0.946               1.710
# 25             0.968               1.207
# 26             1.007               1.566
# 27             1.167               2.300
# 28             1.792               1.958
# 29             1.222               1.983
# 30             1.664               2.143
# 31             1.630               2.273
# 32             1.442               2.180
# 33             1.417               2.431
# 34             2.151               1.897
# 35             1.961               2.134
# 36             2.110               2.044
# 37             2.037               2.023
# 38             1.996               1.791
# 39             2.034               2.004

# %%
result.to_csv(cache_dir_plt+"/max_signal_after_choice.csv")
