# %% [markdown]
# # Notebook 7c:

# %% [markdown]
# simple plot ipsi contra combined win stay and lose switch conditions. recordings from the right side hemisphere.

# %%
import os
from pathlib import Path
import pickle
import matplotlib.pyplot as plt

# %%
import Notebook_7_helper_functions as Nb_7

# %%
Nb_name= 'Notebook_7_c'
period_of_interest = "combined_periods_1"

# %%
mouse = 'T240'
data_day = '2019_09_27__T240'
date = '2019_09_27'

HowManyBack = 1

seq_str= "0a1b2a3c4abcde5a6a7c"

data_dir_output = "/Users/gilmandelbaum/Desktop/outPut"

#corresponds to the number 3 notebooks: 
y_axis_list = ["df_f","z_score","z_score_sliding_window"]

# %% [markdown]
# same for all 7 notebooks

# %%
alphabet = ["a","b","c","d","e","f","g"]
y_axis = y_axis_list[alphabet.index(seq_str[:seq_str.index('4')][-1])]
print (y_axis)
# Out:
# z_score_sliding_window

# %%
version_to_import = seq_str[:seq_str.index('7')][-1]

# %%
root = Path(data_dir_output+"/"+mouse+"/"+data_day+'/'+str(HowManyBack)+"_Back")
d = mouse+"_"+date+"Notebook_6_"+version_to_import+"_"+'seq'+seq_str[:seq_str.index('7')]+'.pickle'

my_path = root / d 
print (my_path)
        
# open a file, where you stored the pickled data
fileToOpen = open(my_path, 'rb')
# load the pickle: 
PhotoData_perTrial_channels = pickle.load(fileToOpen)
# Out:
# /Users/gilmandelbaum/Desktop/outPut/T240/2019_09_27__T240/1_Back/T240_2019_09_27Notebook_6_a_seq0a1b2a3c4abcde5a6a.pickle

# %%
# stash result in a cache directory, for how many back. 
cache_dir_plt = os.path.join(data_dir_output+'/'+mouse+'/'+data_day, str(HowManyBack)+'_Back',"0.plots","session_plots_"+y_axis)
if not os.path.exists(cache_dir_plt):
    os.makedirs(cache_dir_plt)

# %%
path_to_plot = cache_dir_plt+"/"+seq_str
print (path_to_plot)
# Out:
# /Users/gilmandelbaum/Desktop/outPut/T240/2019_09_27__T240/1_Back/0.plots/session_plots_z_score_sliding_window/0a1b2a3c4abcde5a6a7c

# %% [markdown]
# # extract data of interest_right_side

# %%
l_ls_combined_periods_1_d1= Nb_7.extract_data_of_interest_ipsi_contra_per_session(PhotoData_perTrial_channels,
                                                                      1,0,"combined_periods_1","d1 L")

# %%
l_ls_combined_periods_1_d2= Nb_7.extract_data_of_interest_ipsi_contra_per_session(PhotoData_perTrial_channels,
                                                                      1,0,"combined_periods_1","d2 L")

# %%
l_wr_combined_periods_1_d1= Nb_7.extract_data_of_interest_ipsi_contra_per_session(PhotoData_perTrial_channels,
                                                                      1,3,"combined_periods_1","d1 L")

# %%
l_wr_combined_periods_1_d2= Nb_7.extract_data_of_interest_ipsi_contra_per_session(PhotoData_perTrial_channels,
                                                                      1,3,"combined_periods_1","d2 L")

# %% [markdown]
# # calculate_mean_sem per session_right_side

# %%
l_ls_combined_periods_1_d1_mean_sem = Nb_7.calculate_mean_sem (l_ls_combined_periods_1_d1)

# %%
l_ls_combined_periods_1_d2_mean_sem = Nb_7.calculate_mean_sem(l_ls_combined_periods_1_d2)

# %%
l_wr_combined_periods_1_d1_mean_sem = Nb_7.calculate_mean_sem(l_wr_combined_periods_1_d1)

# %%
l_wr_combined_periods_1_d2_mean_sem = Nb_7.calculate_mean_sem(l_wr_combined_periods_1_d2)

# %% [markdown]
# # make_sem_traces_right_side

# %%
l_ls_combined_periods_1_d1_sem_traces = Nb_7.make_sem_traces(l_ls_combined_periods_1_d1_mean_sem)

# %%
l_ls_combined_periods_1_d2_sem_traces = Nb_7.make_sem_traces(l_ls_combined_periods_1_d2_mean_sem)

# %%
l_wr_combined_periods_1_d1_sem_traces = Nb_7.make_sem_traces(l_wr_combined_periods_1_d1_mean_sem)

# %%
l_wr_combined_periods_1_d2_sem_traces = Nb_7.make_sem_traces(l_wr_combined_periods_1_d2_mean_sem)

# %% [markdown]
# # plot_right_side

# %%
Nb_7.plot_ipsi_contra_together(l_ls_combined_periods_1_d1_mean_sem,
                               l_ls_combined_periods_1_d1_sem_traces,
                               "left_side_lose switch","D1",y_axis,path_to_plot)

# %%
Nb_7.plot_ipsi_contra_together(l_ls_combined_periods_1_d2_mean_sem,
                               l_ls_combined_periods_1_d2_sem_traces,
                              "left_side_lose switch","D2",y_axis,path_to_plot)

# %%
Nb_7.plot_ipsi_contra_together(l_wr_combined_periods_1_d1_mean_sem,
                               l_wr_combined_periods_1_d1_sem_traces,
                              "left_side_win repeat","D1",y_axis,path_to_plot)

# %%
Nb_7.plot_ipsi_contra_together(l_wr_combined_periods_1_d2_mean_sem,
                               l_wr_combined_periods_1_d2_sem_traces,
                               "left_side_win repeat","D2",y_axis,path_to_plot)

# %%
root = Path(data_dir_output+"/"+mouse+"/"+data_day+'/'+str(HowManyBack)+"_Back")
d = mouse+"_"+date+Nb_name+'_seq'+seq_str+'.pickle'
my_path = root / d 
my_file = open(my_path, 'wb')
my_file = pickle.dump((),my_file)
